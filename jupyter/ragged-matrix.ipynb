# %%
(* Ragged matrix, i.e. lists of lists *)

structure RaggedMatrix = struct

open List

(* the first index is the length of the outer list; the second is the maximal length of the inner lists *)       
datatype rmat 'a {m : Nat} : {Nat} =
         Nil2 of rmat 'a {m} {0}
       | Cons2 {n m' : Nat} {m' <= m} of list 'a {m'} * rmat 'a {m} {n} --> rmat 'a {m} {n+1}

fun map ['a 'b] {m n : Nat} (f : forall {m : Nat}, list 'a {m} -- $(m*m) --> 'b) (l : rmat 'a {m} {n}) return list 'b {n} using $(m * m + 3) * $n =
    case l of
        Nil2 => []
      | Cons2 (x, xs) => f x :: map @f xs

end
# Out:
# Input file(s):
#   ../examples/stdlib.pkg
#   timl-jupyter-tmp.timl
# Typechecking file ../examples/basic.timl ...
# Type checker generated 0 proof obligations.
# Typechecking results for ../examples/basic.timl:
#
# structure Basic :
#   sig
#     bool :: (Type)
#     ibool :: (Bool => Type)
#     option :: (Type => Type)
#     le :: (Nat * Nat => Type)
#   end
#
#
# Typechecked.
#
# Typechecking file ../examples/list.timl ...
# Type checker generated 8 proof obligations.
# -------------------------------------------
# Applying BigO solver ...
# solve_vcs ()
# Infer and check ...
# use_master_theorem ()
# by_master_theorem ()
# Failed the [T m (n/b)] case because: bs is null
# Try [T m (n-1)] case ...
# Yes! I solved this: (fn (m : Nat) (n : Nat) => (($ m) * ($ n)))
#
# Inferred! Now check inferred complexity (fn (m : Nat) (n : Nat) => (($ m) * ($ n))) against specified complexity (fn (m : Nat) (n : Nat) => (($ m) * ($ n)))
# Complexity check OK!
# Infer and check ...
# use_master_theorem ()
# by_master_theorem ()
# Failed the [T m (n/b)] case because: bs is null
# Try [T m (n-1)] case ...
# Yes! I solved this: (fn (m : Nat) (n : Nat) => (($ m) * ($ n)))
#
# Inferred! Now check inferred complexity (fn (m : Nat) (n : Nat) => (($ m) * ($ n))) against specified complexity (fn (m : Nat) (n : Nat) => (($ m) * ($ n)))
# Complexity check OK!
# Infer and check ...
# use_master_theorem ()
# by_master_theorem ()
# Failed the [T (n/b)] case because: bs is null
# Try [T (n-1)] case ...
# Yes! I solved this: (fn (n : Nat) => ($ n))
#
# Inferred! Now check inferred complexity (fn (n : Nat) => ($ n)) against specified complexity (fn (n : Nat) => ($ n))
# Complexity check OK!
# Infer and check ...
# use_master_theorem ()
# by_master_theorem ()
# Yes! I solved this: (fn (n : Nat) => ($ n))
#
# Inferred! Now check inferred complexity (fn (n : Nat) => ($ n)) against specified complexity (fn (n : Nat) => ($ n))
# Complexity check OK!
# BigO solver generated or left 8 proof obligations unproved.
#
# -------------------------------------------
# Applying SMT solver ...
# SMT solver generated or left 0 proof obligations unproved.
#
# Typechecking results for ../examples/list.timl:
#
# structure List :
#   sig
#     T_map ::: { __f : Fun 2 | (__f <== (fn (m : Nat) (n : Nat) => (($ m) * ($ n)))) }
#     T_foldl ::: { __f : Fun 2 | (__f <== (fn (m : Nat) (n : Nat) => (($ m) * ($ n)))) }
#     T_rev_append ::: { __f : Fun 1 | (__f <== (fn (n : Nat) => ($ n))) }
#     T_rev ::: { __f : Fun 1 | (__f <== (fn (n : Nat) => ($ n))) }
#     list :: (Type => Nat => Type)
#     map : (forall 'a 'b {m : Nat} {n : Nat}, (('a -- ($ m) --> 'b) -> ((list 'a {n}) -- (T_map m n) --> (list 'b {n}))))
#     foldl : (forall 'a 'b {m : Nat} {n : Nat}, ((('a * 'b) -- ($ m) --> 'b) -> ('b -> ((list 'a {n}) -- ((($ m) + ($ 4)) * ($ n)) --> 'b))))
#     foldl : (forall 'a 'b {m : Nat} {n : Nat}, ((('a * 'b) -- ($ m) --> 'b) -> ('b -> ((list 'a {n}) -- (T_foldl m n) --> 'b))))
#     hd : (forall 'a {n : { n : Nat | (n > 0) }}, ((list 'a {n}) -> 'a))
#     rev_append : (forall 'a {n : Nat} {m : Nat}, (((list 'a {n}) * (list 'a {m})) -- ($ n) --> (list 'a {(n + m)})))
#     rev_append_2 : (forall 'a {n1 : Nat} {n2 : Nat}, ((list 'a {n1}) -> ((list 'a {n2}) -- (T_rev_append n1) --> (list 'a {(n1 + n2)}))))
#     rev : (forall 'a {n : Nat}, ((list 'a {n}) -- (T_rev n) --> (list 'a {n})))
#   end
#
#
# Typechecked.
#
# Typechecking file ../examples/nat.timl ...
# Type checker generated 10 proof obligations.
# -------------------------------------------
# Applying BigO solver ...
# solve_vcs ()
# BigO solver generated or left 10 proof obligations unproved.
#
# -------------------------------------------
# Applying SMT solver ...
# SMT solver generated or left 0 proof obligations unproved.
#
# Typechecking results for ../examples/nat.timl:
#
# structure Nat :
#   sig
#     cmp_result :: (Nat * Nat => Type)
#     le_result :: (Nat * Nat => Type)
#     min_max_result :: (Nat * Nat => Type)
#     eq_dec :: (Nat * Nat => Type)
#     lt_dec :: (Nat * Nat => Type)
#     nat_less_than :: (Nat => Type)
#     cmp : (forall {x : Nat} {y : Nat}, (((nat x) * (nat y)) -> (cmp_result {x} {y})))
#     le : (forall {x : Nat} {y : Nat}, (((nat x) * (nat y)) -- 7.0 --> (le_result {x} {y})))
#     min_max : (forall {m : Time} {x : Nat} {y : Nat}, ((((nat x) * (nat y)) -- m --> (le_result {x} {y})) -> (((nat x) * (nat y)) -- (1.0 + m) --> (min_max_result {x} {y}))))
#     eq_dec : (forall {x : Nat} {y : Nat}, (((nat x) * (nat y)) -- 1.0 --> (eq_dec {x} {y})))
#     lt_dec : (forall {x : Nat} {y : Nat}, (((nat x) * (nat y)) -- 1.0 --> (lt_dec {x} {y})))
#     nat_1 : (nat 1)
#     nat_2 : (nat 2)
#     nat_4 : (nat 4)
#     nat_plus : (forall {a : Nat} {b : Nat}, (((nat a) * (nat b)) -- 1.0 --> (nat (a + b))))
#     nat_minus : (forall {a : Nat} {b : Nat} {__omitted_subset_id_name : { __omitted_subset_id_name : Unit | (a >= b) }}, (((nat a) * (nat b)) -- 1.0 --> (nat (a - b))))
#     nat_mult : (forall {a : Nat} {b : Nat}, (((nat a) * (nat b)) -- 1.0 --> (nat (a * b))))
#     nat_max : (forall {a : Nat} {b : Nat}, (((nat a) * (nat b)) -- 1.0 --> (nat (a max b))))
#     floor_half : (forall {n : Nat}, ((nat n) -> (nat (floor (($ n) / 2)))))
#     ceil_half : (forall {n : Nat}, ((nat n) -> (nat (ceil (($ n) / 2)))))
#   end
#
#
# Typechecked.
#
# Typechecking file ../examples/array.timl ...
# Type checker generated 0 proof obligations.
# Typechecking results for ../examples/array.timl:
#
# structure Array :
#   sig
#     bool :: (= Basic.bool :: (Type))
#     ibool :: (= Basic.ibool :: (Bool => Type))
#     option :: (= Basic.option :: (Type => Type))
#     le :: (= Basic.le :: (Nat * Nat => Type))
#     cmp_result :: (= Nat.cmp_result :: (Nat * Nat => Type))
#     le_result :: (= Nat.le_result :: (Nat * Nat => Type))
#     min_max_result :: (= Nat.min_max_result :: (Nat * Nat => Type))
#     eq_dec :: (= Nat.eq_dec :: (Nat * Nat => Type))
#     lt_dec :: (= Nat.lt_dec :: (Nat * Nat => Type))
#     nat_less_than :: (= Nat.nat_less_than :: (Nat => Type))
#     cmp : (forall {x : Nat} {y : Nat}, (((nat x) * (nat y)) -> (cmp_result {x} {y})))
#     le : (forall {x : Nat} {y : Nat}, (((nat x) * (nat y)) -- 7.0 --> (le_result {x} {y})))
#     min_max : (forall {m : Time} {x : Nat} {y : Nat}, ((((nat x) * (nat y)) -- m --> (le_result {x} {y})) -> (((nat x) * (nat y)) -- (1.0 + m) --> (min_max_result {x} {y}))))
#     eq_dec : (forall {x : Nat} {y : Nat}, (((nat x) * (nat y)) -- 1.0 --> (eq_dec {x} {y})))
#     lt_dec : (forall {x : Nat} {y : Nat}, (((nat x) * (nat y)) -- 1.0 --> (lt_dec {x} {y})))
#     nat_1 : (nat 1)
#     nat_2 : (nat 2)
#     nat_4 : (nat 4)
#     nat_plus : (forall {a : Nat} {b : Nat}, (((nat a) * (nat b)) -- 1.0 --> (nat (a + b))))
#     nat_minus : (forall {a : Nat} {b : Nat} {__omitted_subset_id_name : { __omitted_subset_id_name : Unit | (a >= b) }}, (((nat a) * (nat b)) -- 1.0 --> (nat (a - b))))
#     nat_mult : (forall {a : Nat} {b : Nat}, (((nat a) * (nat b)) -- 1.0 --> (nat (a * b))))
#     nat_max : (forall {a : Nat} {b : Nat}, (((nat a) * (nat b)) -- 1.0 --> (nat (a max b))))
#     floor_half : (forall {n : Nat}, ((nat n) -> (nat (floor (($ n) / 2)))))
#     ceil_half : (forall {n : Nat}, ((nat n) -> (nat (ceil (($ n) / 2)))))
#     array : (forall 'a {len : Nat}, (((nat len) * 'a) -- ($ len) --> (arr 'a len)))
#     fromList : (forall 'a {len : Nat}, ((List.list 'a {len}) -- ($ len) --> (arr 'a len)))
#     tabulate : (forall 'a {len : Nat} {m : Time}, (((nat len) * ((nat_less_than {len}) -- m --> 'a)) -- ((m + ($ 1)) * ($ len)) --> (arr 'a len)))
#     length : (forall 'a {len : Nat}, ((arr 'a len) -> (nat len)))
#     sub : (forall 'a {len : Nat} {who : Nat} {__omitted_subset_id_name : { __omitted_subset_id_name : Unit | (who < len) }}, (((arr 'a len) * (nat who)) -> 'a))
#     update : (forall 'a {len : Nat} {who : Nat} {__omitted_subset_id_name : { __omitted_subset_id_name : Unit | (who < len) }}, ((((arr 'a len) * (nat who)) * 'a) -> unit))
#     appi : (forall 'a {m : Time} {len : Nat}, ((((nat_less_than {len}) * 'a) -- m --> unit) -> ((arr 'a len) -- ((m + ($ 1)) * ($ len)) --> unit)))
#     app : (forall 'a {m : Time} {len : Nat}, (('a -- m --> unit) -> ((arr 'a len) -- ((m + ($ 1)) * ($ len)) --> unit)))
#     modifyi : (forall 'a {m : Time} {len : Nat}, ((((nat_less_than {len}) * 'a) -- m --> 'a) -> ((arr 'a len) -- ((m + ($ 1)) * ($ len)) --> unit)))
#     modify : (forall 'a {m : Time} {len : Nat}, (('a -- m --> 'a) -> ((arr 'a len) -- ((m + ($ 1)) * ($ len)) --> unit)))
#     foldli : (forall 'a 'b {m : Time} {len : Nat}, (((((nat_less_than {len}) * 'a) * 'b) -- m --> 'b) -> ('b -> ((arr 'a len) -- ((m + ($ 1)) * ($ len)) --> 'b))))
#     foldri : (forall 'a 'b {m : Time} {len : Nat}, (((((nat_less_than {len}) * 'a) * 'b) -- m --> 'b) -> ('b -> ((arr 'a len) -- ((m + ($ 1)) * ($ len)) --> 'b))))
#     foldl : (forall 'a 'b {m : Time}, ((('a * 'b) -- m --> 'b) -> ('b -> (forall {len : Nat}, ((arr 'a len) -- ((m + ($ 1)) * ($ len)) --> 'b)))))
#     foldr : (forall 'a 'b {m : Time}, ((('a * 'b) -- m --> 'b) -> ('b -> (forall {len : Nat}, ((arr 'a len) -- ((m + ($ 1)) * ($ len)) --> 'b)))))
#     find : (forall 'a {m : Time}, (('a -- m --> bool) -> (forall {len : Nat}, ((arr 'a len) -- ((m + ($ 1)) * ($ len)) --> (option 'a)))))
#     exi_sts : (forall 'a {m : Time}, (('a -- m --> bool) -> (forall {len : Nat}, ((arr 'a len) -- ((m + ($ 1)) * ($ len)) --> bool))))
#     all : (forall 'a {m : Time}, (('a -- m --> bool) -> (forall {len : Nat}, ((arr 'a len) -- ((m + ($ 1)) * ($ len)) --> bool))))
#     toList : (forall 'a {len : Nat}, ((arr 'a len) -- ($ len) --> (List.list 'a {len})))
#   end
#
#
# Typechecked.
#
# Typechecking file timl-jupyter-tmp.timl ...
# Type checker generated 1 proof obligations.
# -------------------------------------------
# Applying BigO solver ...
# solve_vcs ()
# BigO solver generated or left 1 proof obligations unproved.
#
# -------------------------------------------
# Applying SMT solver ...
# SMT solver generated or left 0 proof obligations unproved.
#
# Typechecking results for timl-jupyter-tmp.timl:
#
# structure RaggedMatrix :
#   sig
#     T_map ::: { __f : Fun 2 | (__f = List.T_map) }
#     T_foldl ::: { __f : Fun 2 | (__f = List.T_foldl) }
#     T_rev_append ::: { __f : Fun 1 | (__f = List.T_rev_append) }
#     T_rev ::: { __f : Fun 1 | (__f = List.T_rev) }
#     list :: (= List.list :: (Type => Nat => Type))
#     rmat :: (Type => Nat * Nat => Type)
#     map : (forall 'a 'b {m : Nat} {n : Nat}, (('a -- ($ m) --> 'b) -> ((list 'a {n}) -- (T_map m n) --> (list 'b {n}))))
#     foldl : (forall 'a 'b {m : Nat} {n : Nat}, ((('a * 'b) -- ($ m) --> 'b) -> ('b -> ((list 'a {n}) -- ((($ m) + ($ 4)) * ($ n)) --> 'b))))
#     foldl : (forall 'a 'b {m : Nat} {n : Nat}, ((('a * 'b) -- ($ m) --> 'b) -> ('b -> ((list 'a {n}) -- (T_foldl m n) --> 'b))))
#     hd : (forall 'a {n : { n : Nat | (n > 0) }}, ((list 'a {n}) -> 'a))
#     rev_append : (forall 'a {n : Nat} {m : Nat}, (((list 'a {n}) * (list 'a {m})) -- ($ n) --> (list 'a {(n + m)})))
#     rev_append_2 : (forall 'a {n1 : Nat} {n2 : Nat}, ((list 'a {n1}) -> ((list 'a {n2}) -- (T_rev_append n1) --> (list 'a {(n1 + n2)}))))
#     rev : (forall 'a {n : Nat}, ((list 'a {n}) -- (T_rev n) --> (list 'a {n})))
#     map : (forall 'a 'b {m : Nat} {n : Nat}, ((forall {m : Nat}, ((list 'a {m}) -- (($ m) * ($ m)) --> 'b)) -> ((rmat 'a {m} {n}) -- (((($ m) * ($ m)) + ($ 3)) * ($ n)) --> (list 'b {n}))))
#   end
#
#
# Typechecked.
